# %%
import glob
import matplotlib.pyplot as plt
from lightkurve import KeplerTargetPixelFile

# %%
tpfs=glob.glob('attilafiles/*lpd-targ.fits')

# %%
for index, eachtpf in enumerate(tpfs):
    #if index<5:
    if True:
        tpf = KeplerTargetPixelFile(eachtpf)
        plt.scatter(tpf.estimate_centroids()[0],tpf.estimate_centroids()[1],s=5)
        plt.title(eachtpf)
        plt.show()
